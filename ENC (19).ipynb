# %% [markdown]
# # Q. 1. Write a python program to calculate the length of the string

# %%
s=input ("enter the string ")
# Out:
# enter the string Happy new year

# %%
print(s)
# Out:
# Happy new year

# %% [markdown]
# # length of the string

# %%
l1=len(s)

# %%
print ("length of the string:",l1)
# Out:
# length of the string: 14

# %% [markdown]
# # Q2. Python program to calculate the square root

# %%
import math

# %%
print ("the square root of 25 is ", math.sqrt(25))
# Out:
# the square root of 25 is  5.0

# %% [markdown]
# # Q3. write a python program to convert temperature in celsius to temperature in Fahrenheit

# %%
Celsius=20

# %%
Fahrenheit= Celsius*9/5+32

# %%
print (Fahrenheit)
# Out:
# 68.0

# %% [markdown]
# # Q.4 write a data type needed for give data. (10, 4.5,2+6j)

# %%
num=10

# %%
type (num)
# Out:
# int

# %%
num=4.5

# %%
type (num)
# Out:
# float

# %%
num=2+6j

# %%
type (num)
# Out:
# complex
